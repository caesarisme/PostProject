# %%
import os
import sys
import warnings
warnings.filterwarnings('ignore')

# change this property
NOMEROFF_NET_DIR = os.path.abspath('/media/manapov/7ff2a4aa-26aa-48f8-ae2a-9fba42bc53431/Work/POST_project/lstm')

DATASET_NAME = "gybrid"
VERSION = "15"
MODE = "cpu"
PATH_TO_DATASET = os.path.join(NOMEROFF_NET_DIR, "datasets/ocr/", DATASET_NAME)
RESULT_MODEL_PATH = os.path.join(NOMEROFF_NET_DIR, "models/", 'anpr_ocr_{}_{}-{}.h5'.format(DATASET_NAME, VERSION, MODE))

FROZEN_MODEL_PATH = os.path.join(NOMEROFF_NET_DIR, "models/", 'anpr_ocr_{}_{}-{}.pb'.format(DATASET_NAME, VERSION, MODE))

sys.path.append(NOMEROFF_NET_DIR)

from NomeroffNet.Base import OCR, convert_keras_to_freeze_pb
# Out:
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/NomeroffNet/Detector.py:14: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/NomeroffNet/Detector.py:16: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Using TensorFlow backend.

# %%
class kz(OCR):
    def __init__(self):
        OCR.__init__(self)
        # only for usage model
        # in train generate automaticly
        #self.letters = ["А", "Б", "В", "Г", "Д", "Е", "Ё", "Ж", "З", "И", "Й", "К", "Л", "М", "Н", "О", "П", "Р", "С", "Т", "У", "Ф", "Х", "Ц", "Ч", "Ш", "Щ", "Ъ", "Ы", "Ь", "Э", "Ю", "Я","-", "а", "б", "в", "г", "д", "е", "ё", "ж", "з", "и", "й", "к", "л", "м", "н", "о", "п", "р", "с", "т", "у", "ф", "х", "ц", "ч", "ш", "щ", "ъ", "ы", "ь", "э", "ю", "я"]
        self.letters = ["А", "Б", "В", "Г", "Д", "Е", "Ё", "Ж", "З", "И", "Й", "К", "Л", "М", "Н", "О", "П", "Р", "С", "Т", "У", "Ф", "Х", "Ц", "Ч", "Ш", "Щ", "Ъ", "Ы", "Ь", "Э", "Ю", "Я","-"]
        #self.letters = ["-", "А", "Б", "В", "Г", "Д", "Е", "Ж", "З", "И", "Й", "К", "Л", "М", "Н", "О", "П", "Р", "С", "Т", "У", "Х", "Ч", "Ш", "Ы", "Ь", "Ю", "Я"]        
        self.EPOCHS = 3

# %%
ocrTextDetector = kz()
model = ocrTextDetector.prepare(PATH_TO_DATASET, aug_count=0)
# Out:
# GET ALPHABET
# Max plate length in "val": 22
# Max plate length in "train": 22
# Max plate length in "test": 22
# Letters train  {'Б', 'Л', 'Я', 'Т', 'Й', 'Ь', 'Х', 'В', 'К', 'И', 'О', 'А', 'У', 'П', 'М', 'Е', 'Н', 'Д', 'Р', 'Ы', 'Ш', '-', 'Г', 'С', 'Ж', 'Ч', 'З', 'Ю'}
# Letters val  {'Б', 'Л', 'Я', 'Т', 'Й', 'Ь', 'В', 'Х', 'К', 'О', 'А', 'И', 'У', 'П', 'М', 'Е', 'Н', 'Д', 'Р', 'Ы', 'Ш', '-', 'Г', 'С', 'Ж', 'Ч', 'З', 'Ю'}
# Letters test  {'Б', 'Л', 'Я', 'Т', 'Й', 'Х', 'В', 'Ь', 'К', 'А', 'О', 'И', 'У', 'П', 'М', 'Е', 'Н', 'Д', 'Р', 'Ы', 'Ш', '-', 'Г', 'С', 'Ж', 'Ч', 'З', 'Ю'}
# Max plate length in train, test and val do match
# Letters in train, val and test do match
# Letters: - А Б В Г Д Е Ж З И Й К Л М Н О П Р С Т У Х Ч Ш Ы Ь Ю Я
#
# EXPLAIN DATA TRANSFORMATIONS
# /media/manapov/7ff2a4aa-26aa-48f8-ae2a-9fba42bc53431/Work/POST_project/lstm/datasets/ocr/gybrid/train ['-', 'А', 'Б', 'В', 'Г', 'Д', 'Е', 'Ж', 'З', 'И', 'Й', 'К', 'Л', 'М', 'Н', 'О', 'П', 'Р', 'С', 'Т', 'У', 'Х', 'Ч', 'Ш', 'Ы', 'Ь', 'Ю', 'Я'] 22
# Text generator output (data which will be fed into the neutral network):
# 1) the_input (image)
# 2) the_labels (plate number): КЫЗЫЛОРДА is encoded as [11, 24, 8, 24, 12, 15, 17, 5, 1, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29]
# 3) input_length (width of image that is fed to the loss function): 30 == 128 / 4 - 2
# 4) label_length (length of plate number): 9
# START BUILD DATA
# DATA PREPARED

# %%
model = ocrTextDetector.train(mode=MODE)
#ocrTextDetector.test(verbose=True)
# Out:
# START TRAINING
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# the_input_kz (InputLayer)       (None, 128, 64, 1)   0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 64, 16)  160         the_input_kz[0][0]
# __________________________________________________________________________________________________
# max1 (MaxPooling2D)             (None, 64, 32, 16)   0           conv1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 64, 32, 16)   2320        max1[0][0]
# __________________________________________________________________________________________________
# max2 (MaxPooling2D)             (None, 32, 16, 16)   0           conv2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 32, 256)      0           max2[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 32, 32)       8224        reshape[0][0]
# __________________________________________________________________________________________________
# gru1 (GRU)                      (None, 32, 512)      837120      dense1[0][0]
# __________________________________________________________________________________________________
# gru1_b (GRU)                    (None, 32, 512)      837120      dense1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 512)      0           gru1[0][0]
#                                                                  gru1_b[0][0]
# __________________________________________________________________________________________________
# gru2 (GRU)                      (None, 32, 512)      1574400     add_1[0][0]
# __________________________________________________________________________________________________
# gru2_b (GRU)                    (None, 32, 512)      1574400     add_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 1024)     0           gru2[0][0]
#                                                                  gru2_b[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 32, 29)       29725       concatenate_1[0][0]
# __________________________________________________________________________________________________
# softmax_kz (Activation)         (None, 32, 29)       0           dense2[0][0]
# ==================================================================================================
# Total params: 4,863,469
# Trainable params: 4,863,469
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4249: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4229: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4253: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/3
# 11144/11144 [==============================] - 8751s 785ms/step - loss: 4.5922 - val_loss: 6.0882
# Epoch 2/3
# 11144/11144 [==============================] - 8786s 788ms/step - loss: 0.5885 - val_loss: 6.5154
# Epoch 3/3
# 11144/11144 [==============================] - 9359s 840ms/step - loss: 0.6454 - val_loss: 7.3509

# %%
ocrTextDetector.save(RESULT_MODEL_PATH, verbose=True)
#ocrTextDetector.test(verbose=True)
# Out:
# SAVED TO /media/manapov/7ff2a4aa-26aa-48f8-ae2a-9fba42bc53431/Work/POST_project/lstm/models/anpr_ocr_gybrid_15-cpu.h5

# %%
ocrTextDetector.test(verbose=True)
# Out:
# RUN TEST
#
# Predicted: 		 АСТСИ
# True: 			 АСТАНА
#
# Predicted: 		 СЖВАНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАЗБХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 ТУРКЕКТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 МОЛОАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АРТЫИ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 МАЛТОДАВСКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 СОССИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 АТЫРУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АТЮЫРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 СЖНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРАГАНДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 МАТГИРАУСКИЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КАЛАЛАСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АЛМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 УЗАЛНА
# True: 			 УКРАИНА
#
# Predicted: 		 КАЛМОЛНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 АТАРУНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 АЛКОЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 ТАДЖЕКАИСКАН
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ЮЖРНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МАКМИТИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ЮАМБЛКНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 АКТАНА
# True: 			 АСТАНА
#
# Predicted: 		 КАКШЕТАУ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАРАГИЗСТАЯ
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АМОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАЗАГАДИЙНСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КОКШЕТАУ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАЗШХЕСТАН
# True: 			 КОКШЕТАУ
#
# Predicted: 		 АКЛОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАРЕРЕКАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ШЕМКЫНТЙ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 УАСТОЬ-КАМЕНОГАРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 ШЫКТЫНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АКТЮБИНСКАЯ
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ТУРКЕКАСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АСТАНАУ
# True: 			 АСТАНА
#
# Predicted: 		 КИРГИАИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ПАВЛОАЗСИЯ
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ПЕТРЫАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ЖАКЫЛОНАСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 АМЫЛИЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КАНГИЛСТИНСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 УЖТЬ-КАМЕНСГТОРСК
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ВОВТРНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАЗЫГОКАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ТАДЖИКСТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 КАЗЫГРАСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 УРКЕИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КЫЗЫЛГАДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КОРГАУСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ЗОПАДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКХОТАУ
# True: 			 АЛМАТЫ
#
# Predicted: 		 КОВЕОЧОКАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКА
# True: 			 АКТАУ
#
# Predicted: 		 ШЫМАНА
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КУРКЕСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 ЖАКБОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КОЛМОЛИНКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 УРАИНА
# True: 			 УКРАИНА
#
# Predicted: 		 КАЗЫЛОРДИСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КЫРЫЛОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КШЕТАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 УАСТЬ-КАМЕНОГОРСК
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАВРГОЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ВАВЕРНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОРТААЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 УЫРАЛА
# True: 			 ПАВЛОДАР
#
# Predicted: 		 КУЗАХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АЛМЫВСКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КОТАИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 ТУРКЕТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 КАЗЫОЛОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КЫЗАХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 МОЛМЕАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ТЫЗКЫЛНОКЗАХСНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКМОТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ПАЛЫРКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КОКЛОСТАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 КАНБИИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 ЮЖН-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ПАЛОРУССКАЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 АКТОЕ
# True: 			 АКТАУ
#
# Predicted: 		 МАНГИТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АКТБАВИАЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КЫВЛРДИСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 АКМОЛИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 ТУРЕСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АКТЫРУ
# True: 			 АТЫРАУ
#
# Predicted: 		 АЛМОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ПАРБЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КАЛМАТЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 ПАМБЫЛАРИНСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КЫЗЫЛОРНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 УРКЕСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 БЕЛЕРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 ТАБХАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 УЮСТЬ-КАМЕНОГОРК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 ЗАПЖДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 УКРАИА
# True: 			 УКРАИНА
#
# Predicted: 		 АИБХАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КЫЗЫЕТАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 АЛМАТАЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 ПУТРОПАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АЛМАТИЯ
# True: 			 АЛМАТЫ
#
# Predicted: 		 ПАВЛОТАР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ПАВЛОДЬСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ЮЖТОЧН-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОСТАНЙСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 АБТАНА
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КЕЛОРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 ЗАВАДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАЛЫОАРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 ТОКЕТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 АКРТЫКАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ТАВЛОДАРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 МАМБЫЛИЬНСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 ПОТРОПАВАЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АТМОЛАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КАЗЛОРТА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 ТОССИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 УКБЕКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 ПОТОПАРЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 КЫЗЫЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОСТАНЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КОКШЕСТАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 СЕВЖЬНО-КАМАНСТАРСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОЗЛХЕТАУ
# True: 			 КАЗАХСТАН
#
# Predicted: 		 ПАРЛОАУ
# True: 			 ПАВЛОДАР
#
# Predicted: 		 АКМОЛИЬНСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 УКРАИНСК
# True: 			 УКРАИНА
#
# Predicted: 		 КАРАГНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПАТЫРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 УКРАИХНА
# True: 			 УКРАИНА
#
# Predicted: 		 КОРГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КЫЗЫЛОАРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 МАНМИИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 СЕВЕНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АТОНСАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КЫЗЫЛОРДАУ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 УРАЛСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 АКТАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ШЫЛКЕАДАТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 ЮЖНАР
# True: 			 ЮЖНАЯ
#
# Predicted: 		 КОКШЕТУАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 КОСТАСТАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АЛМОИНКА
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ПАВЛОДРУСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ТУРКЕТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АТЫРИУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ПЕТРОАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ВОВЕРНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОКШАУКАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 АТОБЕ
# True: 			 АКТОБЕ
#
# Predicted: 		 АВХАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КАЗАХСТИН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АЛГАЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 АЛМАНТЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 КАРТГАНДАУ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 УОСТЬК-КАМЕНОГОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 ЗАПАДЧНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ТУРКЕКТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 АЛЫОЛРДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 АКТОНА
# True: 			 АКТОБЕ
#
# Predicted: 		 ЖКТДАВСИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ПАВЛОДСДКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ПАВЛОДАУ
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ТАРАУ
# True: 			 ТАРАЗ
#
# Predicted: 		 КАЛАХТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АЛМАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КЫСКЕНТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 ПАБХАИР
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КЫЗЫЛОДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 АТМОИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КЫЗЫГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПАВЛОДАРСКАЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КОЛТОАЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КАРЫЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 ЮАЖНАЯ
# True: 			 ЮЖНАЯ
#
# Predicted: 		 КЫЗЫЛОРДАН
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КЫЗЫЛУЗДКАЯ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 ЮВЕРНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МАЛОДРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 КЕРТОАНСКАЯ
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 КАРАГЧНКАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКТЮОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ЮЖАЯ
# True: 			 ЮЖНАЯ
#
# Predicted: 		 МАНГИСАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АКТАТЫ
# True: 			 АКТОБЕ
#
# Predicted: 		 АЛМАТАУ
# True: 			 КАЗАХСТАН
#
# Predicted: 		 ШЫМКАНТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 ПУВЛОДАРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 КАЗАХСТАУ
# True: 			 КАЗАХСТАН
#
# Predicted: 		 МЫЛДААТИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АТАУ
# True: 			 АКТАУ
#
# Predicted: 		 КАРАГРНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КАЛМААИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 УЗБХЕКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АСТНА
# True: 			 УКРАИНА
#
# Predicted: 		 АРАЬСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 ПАРЛОИАР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ТАРЖЕСАРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 СЕМЕАЗ
# True: 			 ТАРАЗ
#
# Predicted: 		 АТОЛАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АЛМЫЛИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 АТЫАУ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 МАМГИТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 МОРДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ВЮСЖНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРКХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АЛМОИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 АРТОБЕ
# True: 			 АКТОБЕ
#
# Predicted: 		 АТАРАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 АСТОА
# True: 			 АСТАНА
#
# Predicted: 		 КАРАГТАДНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АОКМОЛЙНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАЛАГАНСТАН
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КИРГИЗНИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 АРГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 УОСТЬЧНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КЫЗШИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КАЛМОТАУ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 ТУРКЕССТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 КОЛМААИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КЫЗЫЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 ТУРКЕТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КАРБЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КЫЗЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 АЛБОЛЙСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 ЮАТЮБНИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КОСТАНЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ПАЛМЫДСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 СОМСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 ЖАМЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КЫЗЫЛДИРСДКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 ПАВЛОДАРУСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ТАПРАКАХИНСКАЯ
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 АКМОЛИНСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 БЕВЛОДАРУССКАЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КИРГЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 ЮУСТЬ-КАМЕНОГОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КАРГИАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 АТОБЕ
# True: 			 АКТОБЕ
#
# Predicted: 		 СЕМАЙ
# True: 			 СЕМЕЙ
#
# Predicted: 		 КЫЗГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 АКЛМАТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ЮЖЬ-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КЫРАГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 УКЛЫЛУСИЯ
# True: 			 КАРАГАНДА
#
# Predicted: 		 АКМОЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КАЗЫЛАРДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 БЕЛОРУСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 МАРКЛОНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 УРАЛЬСКЯ
# True: 			 УРАЛЬСК
#
# Predicted: 		 АКТАРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КОЛМАИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ТАРКИСНАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 КАЛГЛОИНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 АЛМАЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АЛМАНИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КЫРАГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 МОЛЫАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АКТЫАУ
# True: 			 АКТАУ
#
# Predicted: 		 ТУРЖИКИТСТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 УЗАХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 УКРАЛЬСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 ТУРАИСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АСТАНА
# True: 			 АБХАЗИЯ
#
# Predicted: 		 АОЛМАИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОРАГАНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 МАЛГЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 АТЕКУ
# True: 			 УРАЛЬСК
#
# Predicted: 		 АКТОБ
# True: 			 АКТОБЕ
#
# Predicted: 		 ЗАПАДНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ТУТРОАЛВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АКМАЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АЛАЛАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 СЕМЕАЙ
# True: 			 СЕМЕЙ
#
# Predicted: 		 ПЕТРОПРАВСКЯ
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 КАРАГЛСДКА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КАРТГАИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КОСТЛНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КЫСТЛОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 ТАРЛЕРСАЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 УКРАИНАЙ
# True: 			 УКРАИНА
#
# Predicted: 		 УКРАГНА
# True: 			 УКРАИНА
#
# Predicted: 		 АОСТНА
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КАРГИТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 КАМЫЛРДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 ЮАПТДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ШЫМАГНА
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КЫМАГХНДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 УРАЛКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 УРАЬСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 КЗБЕКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КОРАНДКАЯ
# True: 			 КАРАГАНДА
#
# Predicted: 		 РОССАЗ
# True: 			 ТАРАЗ
#
# Predicted: 		 ПЕЛОРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 ЮЖНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АТЫРУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АМБЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 АОЛТАНА
# True: 			 КАРАГАНДА
#
# Predicted: 		 АКМОЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ТУРКЕКТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 АОКШЕСТКАУ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АСТОНА
# True: 			 АСТАНА
#
# Predicted: 		 МАЛГНАЙУСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КОКБИНКАЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 АЗЫЛДКАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 КЫЗЫЛОРДАУ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 СЕВЖРНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРКЕСАУНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 ШЫМЫЛНСКАК
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 АМАТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АРМАТАЯ
# True: 			 РОССИЯ
#
# Predicted: 		 ПАВЛОЛРАРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 КЛГТНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АИЛГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 АЛМОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАЛТАНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КОЛРАРНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 УЗБЕКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАВБЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 ТАТЫРАУ
# True: 			 ТАРАЗ
#
# Predicted: 		 АКТАТАУ
# True: 			 АЛМАТЫ
#
# Predicted: 		 ТЫЗБХКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАНБОЛИСЬСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АСТОНА
# True: 			 АСТАНА
#
# Predicted: 		 ТАРКЕСАИНСКАЯ
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 МОРДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ЗАПТОЧНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МОТДААСКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ТАРКОПАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АЛМАТАЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 АКМОЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КАРАГААНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 АТРАУ
# True: 			 АКТАУ
#
# Predicted: 		 БАЛОДРСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 МАВКИССТАСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 АТМЫЛИСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 АКТААУ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 ТАКТАУ
# True: 			 АКТАУ
#
# Predicted: 		 КЕЛОРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 САПАДНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АЛМОТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 УЕСТЬ-КАМЕНОГОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 АЛОРАУИЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КАЗБХИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АЛМАЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ТУРКЕСТАРНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КОМТАНАЙ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МОЛТАААИЯ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КАНГИСТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 КАЗХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 ЗЕВЕРНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МАЛДАЛВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 УЗБЕКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АЛОРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КЫЗЫЛОРИЯ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 РОСМНТ
# True: 			 АЛМАТЫ
#
# Predicted: 		 АКТЮАБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 УЕВЖРНО-КАЗАХСТОРСКЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КЫСЫЛЬСЬКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 УСТЬ-КАМЕНОГОРСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 УСКЬКОККАЗАХСТАНКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АСТАСИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 МЕЛРУСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КАЛОЛРСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 ПКТЮБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КАРГИСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КЫЗЫГЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КЫЗБЛОДТАР
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КОСТАНИ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 МАМБАЛИЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 АЛЫОЛРДИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АСТАНАУ
# True: 			 АСТАНА
#
# Predicted: 		 КОКАИУ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 УРАЬСК
# True: 			 УКРАИНА
#
# Predicted: 		 КРАИНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ТУРКЕСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 МЫЗБЫЛНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КЫКАГАНДТ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КИРАГИНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПЕТРОПАИОРСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 КАРТГАЯ
# True: 			 АКТАУ
#
# Predicted: 		 МОКЛОЛАНСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 КАРАГАИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОКШЕТАЙ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 ТУРКЕИСТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 ЗЕВЕРНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРГААУСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 ТУРАЗ
# True: 			 ТАРАЗ
#
# Predicted: 		 КЕЛОРУССКИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 АБХАЗЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 УСТЬ-КАМНОГОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КЫЗЫЛОДТА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КЕТРОПАРДИНСКАЯ
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 САВТРНКАХАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МОЛДИАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ЮУЖЬ-КАЗМЕНОГОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КОРАГАНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АТЫАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 КАРАГЛОАРНДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КИРГИРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КЫЗЫЛОРВВДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ТАДЖИКИСТАН
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КОКМОКИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ЗАДРНАЗАТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ТАДЖИКИТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 АЛМАТИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 СЕМОЕ
# True: 			 СЕМЕЙ
#
# Predicted: 		 МОРБААВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ПАВЛОДАРЛСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ЗАПТДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 МАНГИСАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 ЗАСАДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ЗАПАДНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 САПАДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ПАВЛОДАРСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КЫЗЫЛОРАРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КЫМБЫКИСТАУ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АОКШАРТАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 АЛАЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАЛТОНАИНСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 СЕВАДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ЗАПАДНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АОЛДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ПОСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 КАЛАГНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 АТЫНРА
# True: 			 АТЫРАУ
#
# Predicted: 		 АСТНИЙ
# True: 			 АСТАНА
#
# Predicted: 		 АБТЫЗРАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 КОСЮОЧН-КЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ПАВЛОДАРЬСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ЮВЖРНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ТЕРЕАЗ
# True: 			 РОССИЯ
#
# Predicted: 		 ШЫМКЫНТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 ТУРКЕСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КЫРЫГОДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КЫЛЫЛОАРДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 УРКХСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 КЫЗАГАРДИ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КЫЗЫЛОРСДКА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 ВАПАДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КЫМКЕНТАТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 УОСТАНАЙСКАК
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ТАРА
# True: 			 ТАРАЗ
#
# Predicted: 		 МАТЫВАЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АЛМОАТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ЗАПАРДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 УОРАСКЯ
# True: 			 УРАЛЬСК
#
# Predicted: 		 СЕВЕРНОКАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АТЫАУ
# True: 			 АКТАУ
#
# Predicted: 		 УАЗАТЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 КОРАЛАДАР
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПАТЫРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КОМТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 УАРГИЛА
# True: 			 УКРАИНА
#
# Predicted: 		 КАРЛОАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КЫЗЫЛОДТАУ
# True: 			 КАЗАХСТАН
#
# Predicted: 		 УРБЕКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 МОЛМААЗСКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ПЕТРОНАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 КАЗМХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КОСТРЧВНБАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АСТАНА
# True: 			 АКТАУ
#
# Predicted: 		 ЖУЗБЕКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 ПОЛДАИ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АТЫАУ
# True: 			 АКТАУ
#
# Predicted: 		 АОСТДАИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КАМАЛДНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КОСТОУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 БАЛМОЛРДКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АЛМОАУ
# True: 			 АЛМАТЫ
#
# Predicted: 		 АКТАКАУ
# True: 			 АЛМАТЫ
#
# Predicted: 		 АТХАЗУИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КАЛАХЛСТН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АКТЮОБИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КЫЗЫКРНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КАЛЫЛОРЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КЫЗЫЛРИНСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 ПАЛАЬСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АМЫЛЕЯ
# True: 			 АКТОБЕ
#
# Predicted: 		 АЛДКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ЖАМБИЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КЕРГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КОКАЕТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 РОМСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 АЛТАНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 АЛМОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАРАГНСДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПАВЛОАРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 КУЗАХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КАКШЕТАУ
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КАКШГАРРИУ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 ТАРКХСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 УЗБЕКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 ТАДЖИКИСТАЯ
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 ЮЖН-КАЗАХСНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКЛОЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КЫЗАГОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОСТАЛНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ШЫМЕНТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 АКТЫРАУ
# True: 			 АКТАУ
#
# Predicted: 		 КАРКГСАНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АКТЮАБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КАРАГНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КАРАГАРНДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КЫЗЛОРДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 ПЕТЮБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 АОСТАНА
# True: 			 АСТАНА
#
# Predicted: 		 ПАВЛОРДАР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 АЛТАТИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 АЛМОТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОСТОНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ПАРКЕАРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 КОЗАЛОЗСДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 АТМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОСТАНКАЙ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 УЗБЕКИСТАУ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АЫЗБЕКИРТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 ТАРСАЗ
# True: 			 ТАРАЗ
#
# Predicted: 		 ТАДКЕКАСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КАЛТАИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 СОССИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 АКМЫТУ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 СОСМСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 АРАНКА
# True: 			 АСТАНА
#
# Predicted: 		 ТАВЛДАЗ
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ШЫМЛСТУ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КОСТГАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 МОЛААВНИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 МАЗЫЛЧОАРНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АТАРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АКТОБИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 СЕВЖНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ПАВЛОТАР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 СЕВЕРНО-КАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ШОКАЕТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 УБОАСДНАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АНЖОНКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 РОССИЯ
# True: 			 АСТАНА
#
# Predicted: 		 КЫЗЫЛОАНДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 СОВЕРЧНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРГИСТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АКМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АСТЫРИУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ПАДТРКИСКАН
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 АСТНА
# True: 			 АКТАУ
#
# Predicted: 		 ШЫМКЫНТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КАРАГАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АЛОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АЛМАЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 РЕССИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 КАКТОЧНОКАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АРААУ
# True: 			 УКРАИНА
#
# Predicted: 		 УКРГИЗНИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КОТЕОЛОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОСТАНАВЛЙСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ТУРКГКСТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 АКМОЛИЬСКАЯ
# True: 			 КАРАГАНДА
#
# Predicted: 		 АОСТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 МАТЫРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 ТУРКЕАСТАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 АЛМОЛИСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 МАБЛОЛРВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КОКШЕНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 АКТАУ
# True: 			 РОССИЯ
#
# Predicted: 		 ТУКБЕСТАЯ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАРЛОНРХНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ЗАПТОЧНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КЫЗЫЛЬРСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 АЛОРАУСКАЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 ПАСТОДНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АОТЫРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КЫЗАЕТАН
# True: 			 КОКШЕТАУ
#
# Predicted: 		 КАЗАГХСТАЯ
# True: 			 КАРАГАНДА
#
# Predicted: 		 АЛТАУСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 АЛМЫРАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 СЕВЕНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАЖЕОЧНОКАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АЛМОТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КАЗЕЛНО-КАЗАХСТАРНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАБГАЗНИЙ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 ПАВЛОДАЯ
# True: 			 ПАВЛОДАР
#
# Predicted: 		 УМАЛЬСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 УАРБЛСАЯ
# True: 			 УКРАИНА
#
# Predicted: 		 АМАИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 УВБЛЬМЕНОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 АКТЮЫАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КАЗАГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 МАЛМАТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ВОТЮБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КРГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 ПАВЛОТАР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 КАРМЕРИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 ПЕЛОРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 АСТОНБ
# True: 			 АКТОБЕ
#
# Predicted: 		 УОРСИЯ
# True: 			 УРАЛЬСК
#
# Predicted: 		 АКМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ВОСТОЧНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАЛРОАРСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 УРАЛЬСК
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АЛМААУЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 АКТРОЛТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 СЕСТОЧНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАЗАГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КОКШЕСКАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 РОМСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 ТАДЖИКИСТАЯ
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 ПЕТРОПАВЛОВСКН
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ТАДЖИКИСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 ТУРКЕТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 ЖАМБЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 МАЛТОРДАУ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КАМБЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 АЛГТИНСКАЯ
# True: 			 КАРАГАНДА
#
# Predicted: 		 ВОСТОЧНО-КАЗАХСОТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ТУРКРСАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АКТЮБРУСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КЫЗЫЛНОКАРХДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 МАЗКИТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКМЮЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 СЕВЖЕНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АТАУ
# True: 			 АКТАУ
#
# Predicted: 		 АТЫУИНСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АЛДАВКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КОКШЕИТАУ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 МОЛДААВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АТЫАУ
# True: 			 РОССИЯ
#
# Predicted: 		 КАНГИСТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АТХАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 АКТААУ
# True: 			 АКТАУ
#
# Predicted: 		 АКТМБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КАПАДНО-КАМЕНОГАРСКЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАМЫЛИНСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КЕТРОПАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ТОСТАНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 АКТОАУ
# True: 			 АКТАУ
#
# Predicted: 		 КАРАГБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 ТАРКОСАРНСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ЮЖНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АСТААЯ
# True: 			 АСТАНА
#
# Predicted: 		 АТЫРАУСКАК
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 МАНГИАТАНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 КЫЗЫЛОЗДИ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КУКТОЬНКАХСЬСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КАКТАКА
# True: 			 КОКШЕТАУ
#
# Predicted: 		 КАРЫГЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КОРГИНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 МОЛДААВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КОРГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КАРГАДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АЛХАРИУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ПАМБЛНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КУЗБХКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 АКТЫРАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ТУРКЕКИСТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 КЫЗЫГТАРУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 КЫРАГОДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 УРАЛСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 АТЫАУ
# True: 			 АКТАУ
#
# Predicted: 		 ЮВЕРНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КЫРГЕСКАЯ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КЫРКГНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 СОСЕЙ
# True: 			 РОССИЯ
#
# Predicted: 		 АКМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 МОЛАЛДАВНКА
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 СУРЕГН-КАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ЮЖН-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АЛМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОРАЕНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 ВЮЖЧН-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ПАВГИОУСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 МАМГИСТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АТМАНА
# True: 			 АТЫРАУ
#
# Predicted: 		 МАБХАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 ТУРКЕКАИСКАЯ
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ТУРКОПАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ПАРБЫДРИНСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 САКТОБЕ
# True: 			 АКТОБЕ
#
# Predicted: 		 АЛМАИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ПАВЛОСДАР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ПАРОАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 КЫМТАНДАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АЛТРРАУСКАЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 МКНГИССТУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 ВАЖДНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АКТЮБЬНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 АКРТАНА
# True: 			 УКРАИНА
#
# Predicted: 		 КОСМЕАЙ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КОРАИНИЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АТЮЫРАУУНСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АТХАДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ЖАМБЫЛЬНЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 КИБХАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 АЛМАИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ТАРКЕТРСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КИРАГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПАЛТДАРЛВСКИЯ
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 СОСЕЙ
# True: 			 РОССИЯ
#
# Predicted: 		 УЛМЕКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 УРКЕКСКАЯ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 КАКЫЛИСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 ПАВЛОРДАР
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 МАЛМГИТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОРАГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КАЛМАТЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 УОРСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 КЫЗЛОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КАРАИНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КРХИНИА
# True: 			 УКРАИНА
#
# Predicted: 		 ПАБХАЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 КЫЗЫЛОРИНСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 АСТАНАЕ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АСТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АКТОАУ
# True: 			 АКТАУ
#
# Predicted: 		 ТАРАУ
# True: 			 ТАРАЗ
#
# Predicted: 		 АКМГЛДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 АКРТАНСА
# True: 			 УКРАИНА
#
# Predicted: 		 АТОНА
# True: 			 АСТАНА
#
# Predicted: 		 АМАТЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 УЗБХКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАНГИРУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АКМАТАУ
# True: 			 АЛМАТЫ
#
# Predicted: 		 СЕМЕЙ
# True: 			 РОССИЯ
#
# Predicted: 		 АЛМЮИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 АЛМОЛИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 ЖАКМОЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 УАЗБЕКСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 КАРАГИРАУ
# True: 			 КАРАГАНДА
#
# Predicted: 		 АКМОИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 АСТАНТ
# True: 			 АСТАНА
#
# Predicted: 		 КАРАГАДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 УАТЫНАУ
# True: 			 УРАЛЬСК
#
# Predicted: 		 ШЫМКЕСДТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 УЗЕЬ-КАМЕНОГОТРК
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОРТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 ПАНГИСТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АРАЛЬСК
# True: 			 УРАЛЬСК
#
# Predicted: 		 КОСТЕАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 СКМТЕ
# True: 			 АКТОБЕ
#
# Predicted: 		 ТУРКЕТСТНАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 КУРАЕСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АЛМОТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АОСТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 УРБЕКИУСТАУ
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 ВОПТДНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ЮУСТЬ-КАМЕНОГОРСК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 АЛМАТЫ
# True: 			 АСТАНА
#
# Predicted: 		 КОЗБАНЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КЫСКЕСКАЯ
# True: 			 РОССИЯ
#
# Predicted: 		 КИРГИЗЗСИЙ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КЫЗЫОЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОТЫРАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 ПЕЛОРУССИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КЫЗЫОРДИЯ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 АОЛТОААЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ТАРКОСТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КОСТАНИЯ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 КОСТАНАЙ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОЗШХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КАРКГАИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 ЗАПАДНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 УКРГИНА
# True: 			 УКРАИНА
#
# Predicted: 		 АКЮБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КУЗКЕСТАН
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 УРКЛНДК
# True: 			 ПАВЛОДАР
#
# Predicted: 		 АЛМАЛТЫ
# True: 			 АЛМАТЫ
#
# Predicted: 		 АКТОБ
# True: 			 АКТОБЕ
#
# Predicted: 		 КАЗГЛСРАЯ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 ТУРКЕТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 КЫЗАГОАДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 УКРАЛНА
# True: 			 УКРАИНА
#
# Predicted: 		 КАКАЛНДАУ
# True: 			 КАРАГАНДА
#
# Predicted: 		 АЛМАУНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 АЛМИЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ВОВАДНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАДЖИКИСТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 МАНГИТУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 КЕВАЛНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 РОССЕАЯ
# True: 			 РОССИЯ
#
# Predicted: 		 ПЕТРОНИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КОРГИЙЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 УАРДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ЗАПАДНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРАГНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ШЫМЕНТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 АОСТАНИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 ЮЕЖНО-КАЗАХСТАНСКАЯ
# True: 			 ЮЖНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОЗЫЛОРДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 ПАВЛОЛАРЬСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 АБХЗИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 ТУРКЕСАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 АРГАУНСКАЯ
# True: 			 КАРАГАНДА
#
# Predicted: 		 КАРАГНДНА
# True: 			 КАРАГАНДА
#
# Predicted: 		 ПАТЫРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 КАМГЫЛЗСКАЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 ВЮСЖОНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КОЗТЛРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КИСТИНИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 КЫДАГАНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АКТОАУ
# True: 			 АКТАУ
#
# Predicted: 		 ЮОЛДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АМЫЛИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 СЕСИЯ
# True: 			 СЕМЕЙ
#
# Predicted: 		 КЫРЛЕДКРАДСИНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 СЕМНАУ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АСХАСИЯ
# True: 			 АБХАЗИЯ
#
# Predicted: 		 АЛМОИНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРАГАНДИНСКЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 УАЖДН-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АЛМАСТЫ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КОРГАИРУССКИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КАЗЫЛОРДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 БЕВЛОСДАЯ
# True: 			 ПАВЛОДАР
#
# Predicted: 		 ВОЖТНО-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АНГИСТАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 ПАВЛОДАРДНСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 КАРЫГЗНДАН
# True: 			 КАРАГАНДА
#
# Predicted: 		 МАНГИСТАСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 КОКМТАН
# True: 			 КОКШЕТАУ
#
# Predicted: 		 КЫЗЫГОДА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 АКТААЯ
# True: 			 АСТАНА
#
# Predicted: 		 УРАГНТА
# True: 			 УКРАИНА
#
# Predicted: 		 ТАРЛЕСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 ШЫМКОНТИТ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 КОРАГИНА
# True: 			 КАРАГАНДА
#
# Predicted: 		 КТБАСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 АЛМАТВКИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 АТАНА
# True: 			 АСТАНА
#
# Predicted: 		 КОЛАИТИН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КАРГИЗИЯ
# True: 			 КИРГИЗИЯ
#
# Predicted: 		 УКРАИСА
# True: 			 УКРАИНА
#
# Predicted: 		 ЮЖН-СРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 УЗБХЕКИСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АКТЮБИНСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 БЕРЛОАСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 МАТДЫДАВИЯ
# True: 			 МОЛДАВИЯ
#
# Predicted: 		 КАНГИОРДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 ТАРЖИКИСТАН
# True: 			 ТАДЖИКИСТАН
#
# Predicted: 		 МАЛОСТАЯ
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КОЗТЕНЙСКАН
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КАНЫГАНДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОКШЕЬСКАУ
# True: 			 КОКШЕТАУ
#
# Predicted: 		 КОЛТОНАЗАДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КУРКЕСТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АОЛМАНИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КАКТОНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 ЖАТБЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 САВТДЧНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 КАРГАНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 УАЛАСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 ВАВАДН-КАЗАХСТАНСКАЯ
# True: 			 ВОСТОЧНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ТАРЛОЛРСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 АКБЫНАР
# True: 			 УКРАИНА
#
# Predicted: 		 УЫКШЫОРРДАК
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 ЗОПТДЧНО-КАЗАХСТАНСКАЯ
# True: 			 ЗАПАДНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 АТЫРУСКАЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АЗАЫЛТАН
# True: 			 ТУРКЕСТАН
#
# Predicted: 		 АТЫАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 КАЛМААЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 САСТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 ПАДЛОАВЛВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 МАКБОИСАУСКАЯ
# True: 			 МАНГИСТАУСКАЯ
#
# Predicted: 		 АЕЛОРУСИЯ
# True: 			 БЕЛОРУССИЯ
#
# Predicted: 		 КАРЫГЛИНДИСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 КОСТГНАУСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 АКШОЛИНЬСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 КАРКГАНДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 ТАТЫАУ
# True: 			 АТЫРАУ
#
# Predicted: 		 УРКЕИТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 УЖЬНО-КАЗАХСТАНСКАЯ
# True: 			 СЕВЕРНО-КАЗАХСТАНСКАЯ
#
# Predicted: 		 ПАВЛОАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 ПАТОБАУСКАК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АСТАНА
# True: 			 АКТОБЕ
#
# Predicted: 		 КОКШЕТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 КАМБЫЛЬСКАЯ
# True: 			 ЖАМБЫЛЬСКАЯ
#
# Predicted: 		 УРБЕСК
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 СЕРЕАЙ
# True: 			 ТАРАЗ
#
# Predicted: 		 ТАЗКХСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 ПАВЛОДИР
# True: 			 ПАВЛОДАР
#
# Predicted: 		 АОКТАНАЙ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 УСТЬ-КАМЕНОГОРК
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КАЗАГХНДА
# True: 			 КАРАГАНДА
#
# Predicted: 		 АТАНА
# True: 			 АСТАНА
#
# Predicted: 		 УАРГИЛНА
# True: 			 УКРАИНА
#
# Predicted: 		 УЗБХКИСТАН
# True: 			 УЗБЕКИСТАН
#
# Predicted: 		 ПАВЛГЬАРСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 ПАВЛОДАСКАЯ
# True: 			 ПАВЛОДАРСКАЯ
#
# Predicted: 		 ПЕТРОАВЛОВСК
# True: 			 ПЕТРОПАВЛОВСК
#
# Predicted: 		 АТОРАУ
# True: 			 АКТАУ
#
# Predicted: 		 КАРГА
# True: 			 КАРАГАНДА
#
# Predicted: 		 УОСТАНКАЙ
# True: 			 УРАЛЬСК
#
# Predicted: 		 АЛТЛРТА
# True: 			 КЫЗЫЛОРДА
#
# Predicted: 		 КЫЗЫЛОАРНДИНСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 АКТОНАЕ
# True: 			 АСТАНА
#
# Predicted: 		 АКМОТИНСКАЯ
# True: 			 АЛМАТИНСКАЯ
#
# Predicted: 		 КОСТАНАЙНСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КОЗШАСТАН
# True: 			 КАЗАХСТАН
#
# Predicted: 		 АКТЮБРИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 ПОСТАНАЙСКАЯ
# True: 			 КОСТАНАЙСКАЯ
#
# Predicted: 		 КАМШЕЬТУ
# True: 			 УРАЛЬСК
#
# Predicted: 		 КАРАГЕТА
# True: 			 ЮЖНАЯ
#
# Predicted: 		 КЫРАГСОАРДИНСКАЯ
# True: 			 КАРАГАНДИНСКАЯ
#
# Predicted: 		 РОСМСИЯ
# True: 			 РОССИЯ
#
# Predicted: 		 КЕВЕДНО-КАЗАХСТАНСКАЯ
# True: 			 УСТЬ-КАМЕНОГОРСК
#
# Predicted: 		 КОРАНАЙ
# True: 			 КАРАГАНДА
#
# Predicted: 		 АЛЫЛРУСКИЯ
# True: 			 АТЫРАУСКАЯ
#
# Predicted: 		 АЛМБИНСКАЯ
# True: 			 АКТЮБИНСКАЯ
#
# Predicted: 		 КОЛТАЗИЯ
# True: 			 КОСТАНАЙ
#
# Predicted: 		 АКМОБИНСКАЯ
# True: 			 АКМОЛИНСКАЯ
#
# Predicted: 		 АКТОКУ
# True: 			 АКТОБЕ
#
# Predicted: 		 КАРАГАННСКАЯ
# True: 			 КЫЗЫЛОРДИНСКАЯ
#
# Predicted: 		 АКТОБ
# True: 			 АКТОБЕ
#
# Predicted: 		 ПАМКААЙ
# True: 			 ШЫМКЕНТ
#
# Predicted: 		 ТУРКЕСКТАНСКАЯ
# True: 			 ТУРКЕСТАНСКАЯ
#
# Predicted: 		 ТАРАЗ
# True: 			 АТЫРАУ
#
# Predicted: 		 АКТАРАУСКАЯ
# True: 			 АТЫРАУСКАЯ
# acc: 0.7495917256396298

# %%
model = ocrTextDetector.load(RESULT_MODEL_PATH)
# Out:
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2463: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/manapov/miniconda3/envs/nomeroff/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.

# %%
import matplotlib.pyplot as plt
word = plt.imread('/media/manapov/7ff2a4aa-26aa-48f8-ae2a-9fba42bc53431/Work/POST_project/lstm/test/turkestan.jpg')
textArr=ocrTextDetector.predict([word])
print(textArr)
# Out:
# ['ТУРКТАЗ']
